# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from statsmodels.discrete.discrete_model import Logit 
from sklearn.tree import export_graphviz
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV
from  sklearn.metrics import recall_score
from scipy import stats
from sklearn.model_selection import  cross_val_score
from sklearn.metrics import  confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import  roc_curve,accuracy_score
from sklearn.ensemble import  RandomForestClassifier
from sklearn.ensemble import  GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import  roc_curve
from sklearn.ensemble import  RandomForestClassifier
from sklearn.ensemble import  GradientBoostingClassifier

# %%
data=pd.read_csv("final2.csv")
data.drop(columns=data.columns[data.isna().any()].tolist(),inplace=True)
data.drop(columns=['id_val','date'],inplace=True)
data['model']=data["brand"]+"_"+data["model"]
data.drop(columns="brand",inplace=True)

# %%
sns.countplot(x="sold",data=data)
plt.title("Distribution of cars by sold status and Gender")
plt.show()
#let's see percenatage of customers who didn't subscribe to term deposit,
#and percenatage of customers who subscribed to term deposit
print(data.sold.value_counts()/len(data)*100)

#### <p1>as we see our benchmark is about 84 percent our model should predict more precisely</p1>

df_num=data.select_dtypes(exclude="object")## we divide data in this groups to check variance, 
df_object=data.select_dtypes(include="object")
# Out:
# No     70.331775
# Yes    29.668225
# Name: sold, dtype: float64

# %%
### lets create dummies from object variables and final data
df_dummies=pd.get_dummies(df_object,prefix=df_object.columns,drop_first=True)
data3=df_num.join(df_dummies)##corrected dataframe is different from corrected1 it include correleted variables
Y3=data3.sold_Yes
X3=data3.drop("sold_Yes",axis=1)
grid3=GridSearchCV(DecisionTreeClassifier(random_state=42,class_weight="balanced"),
             param_grid={"max_depth":range(50,83,3),
                         "min_samples_leaf":range(40,60,5),
                         },scoring="roc_auc",cv=5,n_jobs=-1).fit(X3,Y3)
params=list(grid3.best_params_.values())
depth,leafs=params
x_train,x_test,y_train,y_test=train_test_split(X3,Y3,test_size=0.2,random_state=42,stratify=Y3)
#tree=DecisionTreeClassifier(random_state=42,class_weight="balanced",max_depth=depth,min_samples_leaf=leafs).fit(x_train,y_train)
train_score=grid3.score(x_train,y_train)
test_score=grid3.score(x_test,y_test)
print(grid3.best_params_)
print("Train score is %s and Test score is%s"%(train_score,test_score))
print("cross_validation score is %s"% (np.mean(cross_val_score(DecisionTreeClassifier(random_state=42,class_weight="balanced",max_depth=depth,min_samples_leaf=leafs),X3,Y3,cv=5))))
y_pred=grid3.predict(x_test)
y_pred2=grid3.predict(x_train)
print(classification_report(y_test,grid3.predict(x_test)))
print("roc_auc: for test is",roc_auc_score(y_test,y_pred))
print("roc_auc: for train is",roc_auc_score(y_train,y_pred2))
print("average Roc_score is",grid3.best_score_)
print("recall for train",recall_score(y_train,y_pred2))
print("recall for test",recall_score(y_test,y_pred))
# Out:
# {'max_depth': 50, 'min_samples_leaf': 50}
# Train score is 0.7202835736075951 and Test score is0.7163686982767221
# cross_validation score is 0.5901723238963499
#               precision    recall  f1-score   support
#
#            0       0.82      0.64      0.72      8815
#            1       0.44      0.68      0.53      3718
#
#    micro avg       0.65      0.65      0.65     12533
#    macro avg       0.63      0.66      0.63     12533
# weighted avg       0.71      0.65      0.66     12533
#
# roc_auc: for test is 0.6575404655556494
# roc_auc: for train is 0.6598993782647302
# average Roc_score is 0.6195996014708542
# recall for train 0.68520137161299
# recall for test 0.6761699838622915

# %%
#ROC curve
x_train,x_test,y_train,y_test=train_test_split(X3,Y3,test_size=0.2,random_state=42,stratify=Y3)
#tree=DecisionTreeClassifier(random_state=42,class_weight="balanced",max_depth=depth,min_samples_leaf=leafs).fit(x_train,y_train)
train_score=grid3.score(x_train,y_train)
test_score=grid3.score(x_test,y_test)
print(grid3.best_params_)
print("cross_validation score is %s"% (np.mean(cross_val_score(DecisionTreeClassifier(random_state=42,class_weight="balanced",max_depth=depth,min_samples_leaf=leafs),X3,Y3,cv=5))))
display(Markdown("<strong> &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;CLASSIFICATION REPORT</strong>" ))

y_pred=grid3.predict(x_test)
y_pred2=grid3.predict(x_train)
print(classification_report(y_test,grid3.predict(x_test)))

print("Overall Accuracy score is ",accuracy_score(y_test,y_pred))
#ROC curve
FPR,TPR,tresholds=roc_curve(y_test,grid3.predict_proba(x_test)[:,1])
plt.plot(FPR,TPR,label="ROC AUC=%f"%roc_auc_score(y_test,y_pred))
plt.title("ROC Curve")
plt.plot([0,1],[0,1])
plt.legend(loc="lower right")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.show()
# Out:
# {'max_depth': 50, 'min_samples_leaf': 50}
# cross_validation score is 0.5901723238963499
# <strong> &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;CLASSIFICATION REPORT</strong>
#               precision    recall  f1-score   support
#
#            0       0.82      0.64      0.72      8815
#            1       0.44      0.68      0.53      3718
#
#    micro avg       0.65      0.65      0.65     12533
#    macro avg       0.63      0.66      0.63     12533
# weighted avg       0.71      0.65      0.66     12533
#
# Overall Accuracy score is  0.649964094789755

# %%
from joblib import dump, load
dump(grid3, 'tree.joblib') 
clf = load('tree.joblib')

# %%
import pickle
with open('mylist', 'wb') as f:
    pickle.dump(X3.columns, f)

# %%
def predict(new):
    from joblib import dump, load
    clf = load('tree.joblib')
    import pickle
    with open("mylist", "rb") as fp:   # Unpickling
        b = pickle.load(fp)
    #new=data[:1]
    #new.drop(columns="sold",inplace=True)
    new['model']=new["brand"]+"_"+new["model"]
    new.drop(columns="brand",inplace=True)
    df_num=new.select_dtypes(exclude="object")## we divide data in this groups to check variance, 
    df_object=new.select_dtypes(include="object")
    #print(df_object)
    ## lets create dummies from object variables and final data
    df_dummies=pd.get_dummies(df_object,prefix=df_object.columns,drop_first=False)
    new=df_num.join(df_dummies)
    for i in b:
        if i not in new.columns:
            new[i]=0
    for i in new.columns:
        if i not in b:
            del new[i]
    class_,probability= clf.predict(new)[0],clf.predict_proba(new)[0][1]
    if class_==0:
        class_="unsold"
    else:
        class_="sold"
    
    print("The probability of the car to be sold is {}, so it is predicted as {}. ".format(probability,class_) )
    return class_,probability

# %%
import pandas as pd
data=pd.read_csv("final2.csv")
z=data[1:2].copy()
z["price"]=2500
predict(z)
# Out:
# The probability of the car to be sold is 0.5140102384754814, so it is predicted as sold.
# ('sold', 0.5140102384754814)

# %%
data
# Out:
#                brand        date        id_val               model    price  \
# 0               Opel    8/2/2018   ID: 1770041              Astra    3000.0
# 1             Toyota    8/2/2018   ID: 1769874              Camry   10000.0
# 2             Nissan    8/2/2018   ID: 1769860            Elgrand    7500.0
# 3         Mitsubishi    8/2/2018   ID: 1770897             Pajero    8500.0
# 4              Mazda    8/2/2018   ID: 1770715                   6  12500.0
# 5             Toyota    8/2/2018   ID: 1769921              Camry    8800.0
# 6              Mazda    8/2/2018   ID: 1769876                CX9    9000.0
# 7             Toyota    8/2/2018   ID: 1770312              Camry   15000.0
# 8                BMW    8/2/2018   ID: 1770022                 318   4000.0
# 9               Opel    8/2/2018   ID: 1770238             Zafira    4300.0
# 10              Opel    8/2/2018   ID: 1770125              Astra    3900.0
# 11               BMW    8/2/2018   ID: 1770817                 X5   15000.0
# 12               BMW    8/2/2018   ID: 1770822                 323   4500.0
# 13     Mercedes-Benz    8/2/2018   ID: 1770849              A 170    4200.0
# 14     Mercedes-Benz    8/2/2018   ID: 1770852              C 240    4800.0
# 15            Nissan    8/2/2018   ID: 1770859            X-Trail    6300.0
# 16     Mercedes-Benz    8/2/2018   ID: 1770933              E 350   12200.0
# 17     Mercedes-Benz    8/2/2018   ID: 1770107              C 200    4400.0
# 18              Opel    8/2/2018   ID: 1770207              Astra    3400.0
# 19            Nissan    8/2/2018   ID: 1770071              Teana    4300.0
# 20           Hyundai    8/2/2018   ID: 1770476             Sonata    8900.0
# 21             Lexus    8/2/2018   ID: 1770669             ES 350   24500.0
# 22              Opel    8/2/2018   ID: 1770874             Zafira    4200.0
# 23     Mercedes-Benz    8/2/2018   ID: 1770129              E 320    4700.0
# 24               BMW    8/2/2018   ID: 1770519                 528   6300.0
# 25               Kia    8/2/2018   ID: 1770787             Optima    9000.0
# 26            Toyota    8/2/2018   ID: 1770520   Land Cruiser 100   17000.0
# 27               BMW    8/2/2018   ID: 1770766                 525   9500.0
# 28             Lexus    8/2/2018   ID: 1770242             GX 470   17550.0
# 29               BMW    8/2/2018   ID: 1770781                 320   6300.0
# ...              ...         ...           ...                 ...      ...
# 62633     Land Rover   10/2/2019   ID: 2008138  Range Rover Sport   50000.0
# 62634     Land Rover   10/2/2019   ID: 2008139  Range Rover Sport   50000.0
# 62635     Land Rover   10/2/2019   ID: 2008136  Range Rover Sport   50000.0
# 62636     Land Rover   10/2/2019   ID: 2008135  Range Rover Sport   50000.0
# 62637     Land Rover   10/2/2019   ID: 2008134  Range Rover Sport   50000.0
# 62638  Mercedes-Benz   10/2/2019   ID: 2006840              E 320    4700.0
# 62639     Land Rover   10/2/2019   ID: 2008137  Range Rover Sport   50000.0
# 62640      Chevrolet   10/3/2019   ID: 2062511             Camaro   15000.0
# 62641          Lexus   11/1/2019   ID: 1961480             LX 570   38000.0
# 62642  Mercedes-Benz   11/2/2019   ID: 2008179            CLS 350   10300.0
# 62643         Nissan   11/2/2019   ID: 2009829              Tiida    4400.0
# 62644            Kia   11/2/2019   ID: 2010053            Sorento    6000.0
# 62645          Lexus   11/2/2019   ID: 2009899             GX 470   16300.0
# 62646  Mercedes-Benz   11/3/2019   ID: 2064062              S 550   22900.0
# 62647  Mercedes-Benz   11/3/2019   ID: 2063345              E 350    8200.0
# 62648            BMW   11/3/2019   ID: 2063179                 X5   15000.0
# 62649         Toyota   11/3/2019   ID: 2062656              Camry   13500.0
# 62650           Opel   12/2/2019   ID: 2010536              Astra    3300.0
# 62651           Opel   12/2/2019   ID: 2010525              Astra    3300.0
# 62652           Opel   12/2/2019   ID: 2010523              Astra    3300.0
# 62653           Opel   12/2/2019   ID: 2010522              Astra    3300.0
# 62654           Opel   12/2/2019   ID: 2010521              Astra    3300.0
# 62655           Opel   12/2/2019   ID: 2010157             Zafira    4200.0
# 62656          Lexus   12/2/2019   ID: 2011339             GX 470   14300.0
# 62657            Kia   12/3/2019   ID: 2064794            Sorento    5500.0
# 62658          Tesla  20.04.2019   ID: 2127306             Model S  59000.0
# 62659         Nissan  20.02.2019   ID: 2026738                Leaf   6900.0
# 62660         Nissan  25.02.2019   ID: 2038748                Leaf   9800.0
# 62661         Nissan  27.10.2018   ID: 1861486                Leaf   8000.0
# 62662         Nissan    8/2/2018   ID: 2031126                Leaf   9000.0
#
#        year        Color         Body_Style  Horsepower Hand_Drive  \
# 0      2003        black          Hatchback         NaN       Left
# 1      2012        black              Sedan         NaN       Left
# 2      2006        White  Minivan / Minibus         NaN      Right
# 3      2007        black             Truck:         NaN       Left
# 4      2015         Grey              Sedan         NaN       Left
# 5      2010        black              Sedan       181.0       Left
# 6      2009        black             Truck:         NaN       Left
# 7      2015        black              Sedan         NaN       Left
# 8      2001       Silver              Sedan       118.0       Left
# 9      2004         Blue  Minivan / Minibus         NaN       Left
# 10     2002        black              Coupe       147.0       Left
# 11     2008        black             Truck:       286.0       Left
# 12     2000        black              Sedan       170.0       Left
# 13     2005        White              Sedan         NaN       Left
# 14     2001       Silver              Sedan         NaN       Left
# 15     2004        black             Truck:         NaN      Right
# 16     2009        White              Sedan         NaN       Left
# 17     2001       Silver              Sedan         NaN       Left
# 18     2003         Blue          Hatchback         NaN       Left
# 19     2005        black              Sedan         NaN       Left
# 20     2011        White              Sedan       201.0       Left
# 21     2012        black              Sedan       277.0       Left
# 22     2003         Blue  Minivan / Minibus         NaN       Left
# 23     2001  Other color              Sedan         NaN       Left
# 24     2000       Silver              Sedan         NaN       Left
# 25     2011        black              Sedan         NaN       Left
# 26     2004        black             Truck:       224.0       Left
# 27     2001        black              Sedan       192.0       Left
# 28     2007        White          Universal         NaN       Left
# 29     2004        black              Sedan         NaN       Left
# ...     ...          ...                ...         ...        ...
# 62633  2008        black             Truck:         NaN       Left
# 62634  2008        black             Truck:         NaN       Left
# 62635  2008        black             Truck:         NaN       Left
# 62636  2008        black             Truck:         NaN       Left
# 62637  2008        black             Truck:         NaN       Left
# 62638  2000        black              Sedan         NaN       Left
# 62639  2008        black             Truck:         NaN       Left
# 62640  2011        White              Coupe         NaN       Left
# 62641  2011        White          Universal         NaN       Left
# 62642  2005       Silver              Sedan       271.0       Left
# 62643  2010       Silver              Sedan         NaN       Left
# 62644  2007       Silver             Truck:         NaN       Left
# 62645  2006        White             Truck:         NaN       Left
# 62646  2012         Grey              Sedan       435.0       Left
# 62647  2007        black              Sedan         NaN       Left
# 62648  2007        green             Truck:         NaN       Left
# 62649  2015     Chestnut              Sedan       181.0       Left
# 62650  2000       Silver          Hatchback       101.0       Left
# 62651  2000       Silver          Hatchback       101.0       Left
# 62652  2000       Silver          Hatchback       101.0       Left
# 62653  2000       Silver          Hatchback       101.0       Left
# 62654  2000       Silver          Hatchback       101.0       Left
# 62655  2005         Blue          Universal         NaN       Left
# 62656  2004        White             Truck:         NaN       Left
# 62657  2006        black          Universal         NaN       Left
# 62658  2016         Grey          Hatchback         NaN       Left
# 62659  2011        White          Hatchback         NaN      Right
# 62660  2011         Grey          Hatchback         NaN       Left
# 62661  2012        black          Hatchback       109.0       Left
# 62662  2011        White          Hatchback         NaN       Left
#
#        Engine_Cylinders      Engine  Engine_Volume Interior_Color   Mileage  \
# 0                   NaN      Petrol            NaN            NaN  140000.0
# 1                   NaN      Petrol            NaN            NaN  102000.0
# 2                   NaN      Petrol            NaN            NaN   75000.0
# 3                   NaN  Astragalus            NaN            NaN  136000.0
# 4                   NaN      Petrol            NaN            NaN   89000.0
# 5                   4.0      Petrol            2.5           Grey   88000.0
# 6                   NaN      Petrol            NaN            NaN  100000.0
# 7                   4.0      Petrol            2.5          black   47000.0
# 8                   6.0      Petrol            1.9          black  190000.0
# 9                   NaN      Diesel            NaN            NaN  260000.0
# 10                  NaN  Astragalus            2.2          black      10.0
# 11                  6.0      Diesel            3.0          black  170000.0
# 12                  6.0      Petrol            2.5          Beige  300000.0
# 13                  NaN      Petrol            NaN            NaN   58000.0
# 14                  NaN  Astragalus            NaN            NaN  250000.0
# 15                  NaN  Astragalus            NaN            NaN   96000.0
# 16                  NaN      Petrol            NaN            NaN  137000.0
# 17                  NaN  Astragalus            NaN            NaN  210000.0
# 18                  NaN      Petrol            NaN            NaN  160000.0
# 19                  NaN      Petrol            NaN            NaN  120000.0
# 20                  NaN      Petrol            2.4            NaN  105000.0
# 21                  6.0      Petrol            3.5          black   81000.0
# 22                  NaN  Astragalus            NaN            NaN  160000.0
# 23                  NaN  Astragalus            NaN            NaN  370000.0
# 24                  NaN  Astragalus            NaN            NaN  161000.0
# 25                  NaN      Petrol            NaN            NaN  103000.0
# 26                  6.0      Petrol            4.5          Beige  200000.0
# 27                  6.0      Petrol            2.5            NaN  210000.0
# 28                  NaN  Astragalus            NaN            NaN  192000.0
# 29                  NaN  Astragalus            NaN            NaN  156000.0
# ...                 ...         ...            ...            ...       ...
# 62633               NaN      Petrol            NaN            NaN  192000.0
# 62634               NaN      Petrol            NaN            NaN  192000.0
# 62635               NaN      Petrol            NaN            NaN  192000.0
# 62636               NaN      Petrol            NaN            NaN  192000.0
# 62637               NaN      Petrol            NaN            NaN  192000.0
# 62638               NaN  Astragalus            NaN            NaN  200000.0
# 62639               NaN      Petrol            NaN            NaN  192000.0
# 62640               NaN      Petrol            NaN            NaN   11111.0
# 62641               NaN      Petrol            5.7          black   98000.0
# 62642               6.0      Petrol            3.5          black   37500.0
# 62643               NaN      Petrol            NaN            NaN   18750.0
# 62644               NaN      Petrol            NaN            NaN  133000.0
# 62645               NaN  Astragalus            NaN            NaN   97000.0
# 62646               8.0      Petrol            5.5          black  111000.0
# 62647               NaN      Petrol            3.5          black  103000.0
# 62648               NaN      Petrol            4.8          Beige  130000.0
# 62649               4.0      Petrol            2.5           Grey   52000.0
# 62650               4.0  Astragalus            1.6            NaN  190000.0
# 62651               4.0  Astragalus            1.6            NaN  190000.0
# 62652               4.0  Astragalus            1.6            NaN  190000.0
# 62653               4.0  Astragalus            1.6            NaN  190000.0
# 62654               4.0  Astragalus            1.6            NaN  190000.0
# 62655               NaN      Petrol            NaN            NaN  123456.0
# 62656               NaN  Astragalus            NaN            NaN  128000.0
# 62657               NaN  Astragalus            NaN            NaN  160400.0
# 62658               NaN    Electric            NaN            NaN   46400.0
# 62659               NaN    Electric            NaN            NaN  100000.0
# 62660               NaN    Electric            NaN            NaN   92800.0
# 62661               NaN    Electric            1.4            NaN   55000.0
# 62662               NaN    Electric            NaN            NaN  110000.0
#
#           Gearbox  Drive_train sold
# 0      Mechanical          NaN   No
# 1       Automatic          NaN  Yes
# 2       Automatic          NaN  Yes
# 3       Automatic          NaN  Yes
# 4       Automatic          NaN  Yes
# 5       Automatic        Front  Yes
# 6       Automatic          NaN   No
# 7       Automatic        Front   No
# 8      Mechanical         Rear  Yes
# 9      Mechanical          NaN   No
# 10     Mechanical          NaN   No
# 11      Automatic  Wheel drive   No
# 12      Automatic         Rear   No
# 13      Automatic          NaN   No
# 14      Automatic          NaN   No
# 15      Automatic          NaN   No
# 16      Automatic          NaN   No
# 17     Mechanical          NaN   No
# 18     Mechanical          NaN   No
# 19      Automatic          NaN  Yes
# 20      Automatic        Front   No
# 21      Automatic        Front   No
# 22     Mechanical          NaN  Yes
# 23      Automatic          NaN   No
# 24      Automatic          NaN   No
# 25      Automatic          NaN   No
# 26      Automatic  Wheel drive   No
# 27      Automatic         Rear   No
# 28      Automatic          NaN   No
# 29      Automatic          NaN   No
# ...           ...          ...  ...
# 62633   Automatic          NaN   No
# 62634   Automatic          NaN   No
# 62635   Automatic          NaN   No
# 62636   Automatic          NaN   No
# 62637   Automatic          NaN   No
# 62638   Automatic          NaN   No
# 62639   Automatic          NaN   No
# 62640   Automatic          NaN   No
# 62641   Automatic          NaN   No
# 62642   Automatic         Rear   No
# 62643   Variator:          NaN   No
# 62644   Automatic          NaN   No
# 62645   Automatic          NaN   No
# 62646   Automatic         Rear   No
# 62647   Automatic         Rear   No
# 62648   Automatic  Wheel drive   No
# 62649   Automatic        Front   No
# 62650  Mechanical        Front   No
# 62651  Mechanical        Front   No
# 62652  Mechanical        Front   No
# 62653  Mechanical        Front   No
# 62654  Mechanical        Front   No
# 62655  Mechanical          NaN   No
# 62656   Automatic          NaN   No
# 62657   Automatic          NaN   No
# 62658   Automatic          NaN   No
# 62659   Automatic          NaN   No
# 62660   Automatic          NaN   No
# 62661    Variator        Front   No
# 62662   Automatic          NaN  Yes
#
# [62663 rows x 18 columns]

# %%
new["brand"]+"_"+new["model"]
# Out:
# 0                          Opel_Astra
# 1                        Toyota_Camry
# 2                      Nissan_Elgrand
# 3                   Mitsubishi_Pajero
# 4                              Mazda_6
# 5                        Toyota_Camry
# 6                           Mazda_CX9
# 7                        Toyota_Camry
# 8                              BMW_318
# 9                         Opel_Zafira
# 10                         Opel_Astra
# 11                             BMW_X5
# 12                             BMW_323
# 13                Mercedes-Benz_A 170
# 14                Mercedes-Benz_C 240
# 15                     Nissan_X-Trail
# 16                Mercedes-Benz_E 350
# 17                Mercedes-Benz_C 200
# 18                         Opel_Astra
# 19                       Nissan_Teana
# 20                     Hyundai_Sonata
# 21                       Lexus_ES 350
# 22                        Opel_Zafira
# 23                Mercedes-Benz_E 320
# 24                             BMW_528
# 25                         Kia_Optima
# 26            Toyota_Land Cruiser 100
# 27                             BMW_525
# 28                       Lexus_GX 470
# 29                             BMW_320
#                      ...
# 62633    Land Rover_Range Rover Sport
# 62634    Land Rover_Range Rover Sport
# 62635    Land Rover_Range Rover Sport
# 62636    Land Rover_Range Rover Sport
# 62637    Land Rover_Range Rover Sport
# 62638             Mercedes-Benz_E 320
# 62639    Land Rover_Range Rover Sport
# 62640                Chevrolet_Camaro
# 62641                    Lexus_LX 570
# 62642           Mercedes-Benz_CLS 350
# 62643                    Nissan_Tiida
# 62644                     Kia_Sorento
# 62645                    Lexus_GX 470
# 62646             Mercedes-Benz_S 550
# 62647             Mercedes-Benz_E 350
# 62648                          BMW_X5
# 62649                    Toyota_Camry
# 62650                      Opel_Astra
# 62651                      Opel_Astra
# 62652                      Opel_Astra
# 62653                      Opel_Astra
# 62654                      Opel_Astra
# 62655                     Opel_Zafira
# 62656                    Lexus_GX 470
# 62657                     Kia_Sorento
# 62658                    Tesla_Model S
# 62659                      Nissan_Leaf
# 62660                      Nissan_Leaf
# 62661                      Nissan_Leaf
# 62662                      Nissan_Leaf
# Length: 62663, dtype: object

# %%
from joblib import dump, load
clf = load('tree.joblib')
import pickle
with open("mylist", "rb") as fp:   # Unpickling
    b = pickle.load(fp)
#new=data[:1]
#new.drop(columns="sold",inplace=True)
df_num=new.select_dtypes(exclude="object")## we divide data in this groups to check variance, 
df_object=new.select_dtypes(include="object")
#print(df_object)
## lets create dummies from object variables and final data
df_dummies=pd.get_dummies(df_object,prefix=df_object.columns,drop_first=False)
new=df_num.join(df_dummies)
for i in b:
    if i not in new.columns:
        new[i]=0
for i in new.columns:
    if i not in b:
        del new[i]
# Out:
#     brand   model    price  year  Color Body_Style Hand_Drive  Engine  \
# 1  Toyota  Camry   10000.0  2012  black      Sedan       Left  Petrol
#
#     Mileage    Gearbox sold
# 1  102000.0  Automatic  Yes

# %%
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))


printmd("**bold text**")
# Out:
# **bold text**
